# %% [markdown]
# # PCA Sensitivity Analysis - Site Classification
#
# ## Objective
# Test whether PCA transformation before harmonization mitigates the harmonization paradox.
#
# ## Experiment Design
# - **Methods tested:** raw, sitewise, combat, neurocombat, covbat
# - **PCA variants:** No PCA (0.0), full variance (1.0), 0.99, 0.95, 0.90, 0.80
# - **Metric:** Site classification MCC (lower = more site-invariant)
#
# ## Key Results
#
# | Method | No PCA | PCA 0.99 | PCA 0.95 | PCA 0.90 | PCA 0.80 |
# |--------|--------|----------|----------|----------|----------|
# | raw | 0.781 | 0.752 | 0.743 | 0.730 | **0.647** |
# | combat | **0.957** | 0.615 | 0.645 | 0.626 | **0.564** |
# | sitewise | 0.965 | 0.638 | 0.654 | 0.649 | 0.576 |
#
# ## Key Insight
# **PCA transformation resolves the paradox.** The key is not dimensionality reduction but the transformation to an orthogonal basis. ComBat's location/scale corrections in the original correlated feature space create cross-feature artifacts that expose site signatures. In PCA space, features are decorrelated, so adjustments are cleaner.
#
# At PCA 0.80: harmonized methods (MCC ~0.56) now have LOWER site classifiability than raw (0.65) - the paradox is reversed.

# %%
import os
from pathlib import Path

if Path.cwd().name != 'eeg-site-effects':
    os.chdir('../..')
print('Working directory:', Path.cwd())
# Out:
# Working directory: /dmj/fizmed/kchorzela/licencjat/eeg-site-effects

# %%
import pandas as pd
import matplotlib.pyplot as plt

RESULTS_PATH_SITE      = 'results/tables/05_pca_sensitivity/pca_sensitivity_results_site.csv'
RESULTS_FULL_PATH_SITE = 'results/tables/05_pca_sensitivity/pca_sensitivity_results_site_full.csv'
FIGURES_DIR            = 'results/figures/05_pca_sensitivity/site_classification'

METHODS      = ['raw', 'sitewise', 'combat', 'neurocombat', 'covbat']
PCA_VARIANTS = [0.0, 1.0, 0.99, 0.95, 0.90, 0.80]

COLOR_GRID = ['black', 'tomato', 'skyblue', 'green', 'orange', 'purple', 'brown', 'cyan']

# %%
site_df      = pd.read_csv(RESULTS_PATH_SITE)
site_full_df = pd.read_csv(RESULTS_FULL_PATH_SITE)

site_df['pca_var']      = site_df['pca_var'].fillna(0.0)
site_full_df['pca_var'] = site_full_df['pca_var'].fillna(1.0)

site_df = pd.concat([site_df, site_full_df], axis=0)
site_mean = (
    site_df
    .groupby(['method', 'pca_var'], dropna=False)
    .mean()
    .drop(columns=['fold_id', 'n_features'], errors='ignore')
)

# %% [markdown]
# ## Site MCC per hospital — grouped by PCA variant

# %%
os.makedirs(FIGURES_DIR, exist_ok=True)

for pca_var in PCA_VARIANTS:
    reference = site_mean.loc['raw', pca_var]
    hospitals_sorted = reference.index.values[reference.values.argsort()[::-1]]

    fig, ax = plt.subplots(figsize=(16, 7))
    for i, method in enumerate(METHODS):
        values = [site_mean.loc[method, pca_var].get(h, float('nan')) for h in hospitals_sorted]
        ax.plot(hospitals_sorted, values, marker='o', linestyle='-',
                color=COLOR_GRID[i], label=method)

    title = f"PCA var={pca_var}" if pca_var != 0.0 else "No PCA"
    ax.set_title(title, fontsize=19)
    ax.set_ylabel("Average MCC", fontsize=13)
    ax.set_xlabel("Hospital ID", fontsize=13)
    ax.tick_params(axis='x', rotation=90)
    ax.set_ylim(0, 1.1)
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    ax.legend(loc='lower right', fontsize=10, ncol=3)
    fig.tight_layout()

    fname = f"site_mcc_pca_{str(pca_var).replace('.', '')}.png"
    fig.savefig(f"{FIGURES_DIR}/{fname}", dpi=150, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## Site MCC per hospital — grouped by method

# %%
for method in METHODS:
    reference = site_mean.loc[method, 0.0]
    hospitals_sorted = reference.index.values[reference.values.argsort()[::-1]]
    pca_vars = site_mean.loc[method].index.unique()

    fig, ax = plt.subplots(figsize=(16, 7))
    for i, pca_var in enumerate(pca_vars):
        values = [site_mean.loc[method, pca_var].get(h, float('nan')) for h in hospitals_sorted]
        label = f"pca_var={pca_var}" if pca_var != 0.0 else "No PCA"
        ax.plot(hospitals_sorted, values, marker='o', linestyle='-',
                color=COLOR_GRID[i], label=label)

    ax.set_title(f"Method: {method}", fontsize=19)
    ax.set_ylabel("Average MCC", fontsize=13)
    ax.set_xlabel("Hospital ID", fontsize=13)
    ax.tick_params(axis='x', rotation=90)
    ax.set_ylim(0, 1.1)
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    ax.legend(loc='lower right', fontsize=10, ncol=3)
    fig.tight_layout()

    fig.savefig(f"{FIGURES_DIR}/site_mcc_method_{method}.png", dpi=150, bbox_inches='tight')
    plt.show()

# %% [markdown]
# # Logistic Regression Analysis

# %%
RESULTS_SITE_LOGREG = 'results/tables/05_pca_sensitivity/pca_sensitivity_results_site_logreg.csv'
MODELS       = ['catboost', 'logreg']
METHODS      = ['raw', 'combat',]
PCA_VARIANTS = ['none', 'all', '0.99', '0.95', '0.9', '0.8']

logreg_df = pd.read_csv(RESULTS_SITE_LOGREG).drop(columns=['model'])
print(logreg_df.shape)
print('methods:', logreg_df['method'].unique())
print('pca_var:', logreg_df['pca_var'].unique())
# Out:
# (60, 44)
# methods: ['raw' 'combat']
# pca_var: ['none' 'all' '0.99' '0.95' '0.9' '0.8']

# %%
logreg_df_mean = (
    logreg_df
    .groupby(['method', 'pca_var'], dropna=False)
    .mean()
    .drop(columns=['fold_id', 'n_features'], errors='ignore')
)

# %%
for pca_var in PCA_VARIANTS:
    reference = logreg_df_mean.loc['raw', pca_var]
    hospitals_sorted = reference.index.values[reference.values.argsort()[::-1]]

    fig, ax = plt.subplots(figsize=(16, 7))
    for i, method in enumerate(METHODS):
        values = [logreg_df_mean.loc[method, pca_var].get(h, float('nan')) for h in hospitals_sorted]
        ax.plot(hospitals_sorted, values, marker='o', linestyle='-',
                color=COLOR_GRID[i], label=method)

    title = f"PCA var={pca_var}" if pca_var != 0.0 else "No PCA"
    ax.set_title(title, fontsize=19)
    ax.set_ylabel("Average MCC", fontsize=13)
    ax.set_xlabel("Hospital ID", fontsize=13)
    ax.tick_params(axis='x', rotation=90)
    ax.set_ylim(0, 1.1)
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    ax.legend(loc='lower right', fontsize=10, ncol=3)
    fig.tight_layout()

    fname = f"site_mcc_pca_{str(pca_var).replace('.', '')}.png"
    #fig.savefig(f"{FIGURES_DIR}/{fname}", dpi=150, bbox_inches='tight')
    plt.show()

# %%
for pca_var in PCA_VARIANTS:
    reference = logreg_df_mean.loc['raw', pca_var]
    hospitals_sorted = reference.index.values[reference.values.argsort()[::-1]]

    fig, ax = plt.subplots(figsize=(16, 7))
    for i, method in enumerate(METHODS):
        values = [logreg_df_mean.loc[method, pca_var].get(h, float('nan')) for h in hospitals_sorted]
        ax.plot(hospitals_sorted, values, marker='o', linestyle='-',
                color=COLOR_GRID[i], label=method)

    title = f"PCA var={pca_var}" if pca_var != 0.0 else "No PCA"
    ax.set_title(title, fontsize=19)
    ax.set_ylabel("Average MCC", fontsize=13)
    ax.set_xlabel("Hospital ID", fontsize=13)
    ax.tick_params(axis='x', rotation=90)
    ax.set_ylim(0, 1.1)
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    ax.legend(loc='lower right', fontsize=10, ncol=3)
    fig.tight_layout()

    fname = f"site_mcc_pca_{str(pca_var).replace('.', '')}.png"
    #fig.savefig(f"{FIGURES_DIR}/{fname}", dpi=150, bbox_inches='tight')
    plt.show()
