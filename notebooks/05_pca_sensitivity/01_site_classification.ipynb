# %% [markdown]
# # PCA Sensitivity Analysis - Site Classification
#
# ## Objective
# Test whether PCA transformation before harmonization mitigates the harmonization paradox.
#
# ## Experiment Design
# - **Methods tested:** raw, sitewise, combat, neurocombat, covbat
# - **PCA variants:** No PCA (0.0), full variance (1.0), 0.99, 0.95, 0.90, 0.80
# - **Metric:** Site classification MCC (lower = more site-invariant)
#
# ## Key Results
#
# | Method | No PCA | PCA 0.99 | PCA 0.95 | PCA 0.90 | PCA 0.80 |
# |--------|--------|----------|----------|----------|----------|
# | raw | 0.781 | 0.752 | 0.743 | 0.730 | **0.647** |
# | combat | **0.957** | 0.615 | 0.645 | 0.626 | **0.564** |
# | sitewise | 0.965 | 0.638 | 0.654 | 0.649 | 0.576 |
#
# ## Key Insight
# **PCA transformation resolves the paradox.** The key is not dimensionality reduction but the transformation to an orthogonal basis. ComBat's location/scale corrections in the original correlated feature space create cross-feature artifacts that expose site signatures. In PCA space, features are decorrelated, so adjustments are cleaner.
#
# At PCA 0.80: harmonized methods (MCC ~0.56) now have LOWER site classifiability than raw (0.65) - the paradox is reversed.

# %%
import os
from pathlib import Path

if Path.cwd().name != 'eeg-site-effects':
    os.chdir('../..')
print('Working directory:', Path.cwd())
# Out:
# Working directory: /dmj/fizmed/kchorzela/licencjat/eeg-site-effects

# %%
import pandas as pd
import matplotlib.pyplot as plt

RESULTS_PATH_CATBOOST = 'results/tables/05_pca_sensitivity/pca_sensitivity_results_site_catboost.csv'
RESULTS_PATH_LOGREG   = 'results/tables/05_pca_sensitivity/pca_sensitivity_results_site_logreg.csv'
FIGURES_DIR           = 'results/figures/05_pca_sensitivity/site_classification'

MODELS       = ['catboost', 'logreg']
METHODS      = ['raw', 'sitewise', 'combat', 'neurocombat', 'covbat']
PCA_VARIANTS = ['none', 'all', '0.99', '0.95', '0.9', '0.8']

# --- Shared palette ---
METHOD_COLORS = {
    'raw':         '#1a1a1a',
    'sitewise':    '#e6550d',
    'combat':      'steelblue',
    'neurocombat': '#31a354',
    'covbat':      '#756bb1',
}

PCA_COLORS = {
    'none': '#1a1a1a',
    'all':  '#2166ac',
    '0.99': '#4393c3',
    '0.95': '#92c5de',
    '0.9':  '#f4a582',
    '0.8':  '#d6604d',
}

MODEL_COLORS  = {'catboost': 'steelblue', 'logreg': 'seagreen'}
MODEL_LABELS  = {'catboost': 'CatBoost',  'logreg': 'Logistic Regression'}

# --- Shared figure settings ---
FIGSIZE_WIDE   = (17, 7)
TITLE_FS       = 14
LABEL_FS       = 12
TICK_FS        = 8
LEGEND_FS      = 10
GRID_ALPHA     = 0.5
LINE_ALPHA     = 0.8
SAVE_DPI       = 150

# %%
catboost_wide = pd.read_csv(RESULTS_PATH_CATBOOST)

# Melt from wide (MCC_HOSPITAL columns) to long format
mcc_cols = [c for c in catboost_wide.columns if c.startswith('MCC_') and c != 'MCC_Overall']
id_cols  = ['MCC_Overall', 'model', 'method', 'fold_id', 'pca_var', 'n_features']
catboost_df = catboost_wide.melt(
    id_vars=[c for c in id_cols if c in catboost_wide.columns],
    value_vars=mcc_cols,
    var_name='hospital', value_name='mcc'
)
catboost_df['hospital'] = catboost_df['hospital'].str.replace('MCC_', '', regex=False)

print(catboost_df.shape)
print('methods:', catboost_df['method'].unique())
print('pca_var:', catboost_df['pca_var'].unique())
catboost_df.head()

# %% [markdown]
# ## CatBoost — MCC per hospital

# %%
os.makedirs(FIGURES_DIR, exist_ok=True)

metric = 'mcc'
baseline = catboost_df[(catboost_df['method'] == 'raw') & (catboost_df['pca_var'] == 'none')]
hospitals_sorted = baseline.groupby('hospital')[metric].mean().sort_values(ascending=False).index.values

# --- By method (subplots faceted by PCA variant) ---
fig, axes = plt.subplots(len(PCA_VARIANTS), 1, figsize=(FIGSIZE_WIDE[0], FIGSIZE_WIDE[1] * len(PCA_VARIANTS)), sharey=True)

for ax, pca in zip(axes, PCA_VARIANTS):
    for method in METHODS:
        sub = catboost_df[(catboost_df['method'] == method) & (catboost_df['pca_var'] == pca)]
        vals = sub.groupby('hospital')[metric].mean().reindex(hospitals_sorted)
        ax.plot(range(len(hospitals_sorted)), vals.values, marker='o',
                color=METHOD_COLORS[method], label=method, alpha=LINE_ALPHA)

    ax.set_title(f'CatBoost — PCA = {pca}', fontsize=TITLE_FS)
    ax.set_xticks(range(len(hospitals_sorted)))
    ax.set_xticklabels(hospitals_sorted, rotation=90, fontsize=TICK_FS)
    ax.set_xlabel('Hospital')
    ax.grid(axis='y', linestyle='--', alpha=GRID_ALPHA)
    ax.legend(fontsize=LEGEND_FS)

axes[0].set_ylabel('MCC', fontsize=LABEL_FS)
fig.tight_layout()
fig.savefig(f"{FIGURES_DIR}/site_mcc_catboost_by_method.png", dpi=SAVE_DPI, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## CatBoost — MCC per hospital, grouped by PCA variant

# %%
# --- By PCA (subplots faceted by method) ---
fig, axes = plt.subplots(len(METHODS), 1, figsize=(FIGSIZE_WIDE[0], FIGSIZE_WIDE[1] * len(METHODS)), sharey=True)

for ax, method in zip(axes, METHODS):
    for pca in PCA_VARIANTS:
        sub = catboost_df[(catboost_df['method'] == method) & (catboost_df['pca_var'] == pca)]
        vals = sub.groupby('hospital')[metric].mean().reindex(hospitals_sorted)
        ax.plot(range(len(hospitals_sorted)), vals.values, marker='o',
                color=PCA_COLORS[pca], label=f'pca={pca}', alpha=LINE_ALPHA)

    ax.set_title(f'CatBoost — Method = {method}', fontsize=TITLE_FS)
    ax.set_xticks(range(len(hospitals_sorted)))
    ax.set_xticklabels(hospitals_sorted, rotation=90, fontsize=TICK_FS)
    ax.set_xlabel('Hospital')
    ax.grid(axis='y', linestyle='--', alpha=GRID_ALPHA)
    ax.legend(fontsize=LEGEND_FS)

axes[0].set_ylabel('MCC', fontsize=LABEL_FS)
fig.tight_layout()
fig.savefig(f"{FIGURES_DIR}/site_mcc_catboost_by_pca.png", dpi=SAVE_DPI, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Logistic Regression Analysis

# %%
logreg_df = pd.read_csv(RESULTS_PATH_LOGREG).drop(columns=['model'], errors='ignore')
print(logreg_df.shape)
print('methods:', logreg_df['method'].unique())
print('pca_var:', logreg_df['pca_var'].unique())

# %%
# Detect format: wide (MCC_HOSPITAL columns) vs long (hospital column)
if 'hospital' not in logreg_df.columns:
    mcc_cols_lr = [c for c in logreg_df.columns if c.startswith('MCC_') and c != 'MCC_Overall']
    id_cols_lr = [c for c in logreg_df.columns if not c.startswith('MCC_') or c == 'MCC_Overall']
    logreg_df = logreg_df.melt(id_vars=id_cols_lr, value_vars=mcc_cols_lr,
                                var_name='hospital', value_name='mcc')
    logreg_df['hospital'] = logreg_df['hospital'].str.replace('MCC_', '', regex=False)
    logreg_metric = 'mcc'
else:
    logreg_metric = 'mcc' if 'mcc' in logreg_df.columns else metric

logreg_baseline = logreg_df[(logreg_df['method'] == 'raw') & (logreg_df['pca_var'] == 'none')]
logreg_hospitals = logreg_baseline.groupby('hospital')[logreg_metric].mean().sort_values(ascending=False).index.values

# %%
# --- LogReg by method (subplots faceted by PCA variant) ---
fig, axes = plt.subplots(len(PCA_VARIANTS), 1, figsize=(FIGSIZE_WIDE[0], FIGSIZE_WIDE[1] * len(PCA_VARIANTS)), sharey=True)

for ax, pca in zip(axes, PCA_VARIANTS):
    for method in METHODS:
        sub = logreg_df[(logreg_df['method'] == method) & (logreg_df['pca_var'] == pca)]
        vals = sub.groupby('hospital')[logreg_metric].mean().reindex(logreg_hospitals)
        ax.plot(range(len(logreg_hospitals)), vals.values, marker='o',
                color=METHOD_COLORS[method], label=method, alpha=LINE_ALPHA)

    ax.set_title(f'LogReg — PCA = {pca}', fontsize=TITLE_FS)
    ax.set_xticks(range(len(logreg_hospitals)))
    ax.set_xticklabels(logreg_hospitals, rotation=90, fontsize=TICK_FS)
    ax.set_xlabel('Hospital')
    ax.grid(axis='y', linestyle='--', alpha=GRID_ALPHA)
    ax.legend(fontsize=LEGEND_FS)

axes[0].set_ylabel('MCC', fontsize=LABEL_FS)
fig.tight_layout()
fig.savefig(f"{FIGURES_DIR}/site_mcc_logreg_by_method.png", dpi=SAVE_DPI, bbox_inches='tight')
plt.show()

# %%
# --- LogReg by PCA (subplots faceted by method) ---
fig, axes = plt.subplots(len(METHODS), 1, figsize=(FIGSIZE_WIDE[0], FIGSIZE_WIDE[1] * len(METHODS)), sharey=True)

for ax, method in zip(axes, METHODS):
    for pca in PCA_VARIANTS:
        sub = logreg_df[(logreg_df['method'] == method) & (logreg_df['pca_var'] == pca)]
        vals = sub.groupby('hospital')[logreg_metric].mean().reindex(logreg_hospitals)
        ax.plot(range(len(logreg_hospitals)), vals.values, marker='o',
                color=PCA_COLORS[pca], label=f'pca={pca}', alpha=LINE_ALPHA)

    ax.set_title(f'LogReg — Method = {method}', fontsize=TITLE_FS)
    ax.set_xticks(range(len(logreg_hospitals)))
    ax.set_xticklabels(logreg_hospitals, rotation=90, fontsize=TICK_FS)
    ax.set_xlabel('Hospital')
    ax.grid(axis='y', linestyle='--', alpha=GRID_ALPHA)
    ax.legend(fontsize=LEGEND_FS)

axes[0].set_ylabel('MCC', fontsize=LABEL_FS)
fig.tight_layout()
fig.savefig(f"{FIGURES_DIR}/site_mcc_logreg_by_pca.png", dpi=SAVE_DPI, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Multi-Model Comparison: CatBoost vs LogReg

# %%
catboost_tagged = catboost_df.assign(model='catboost')
logreg_tagged   = logreg_df.assign(model='logreg')

# Ensure both have the same metric column name
if logreg_metric != 'mcc':
    logreg_tagged = logreg_tagged.rename(columns={logreg_metric: 'mcc'})

multimodel_df = pd.concat([catboost_tagged, logreg_tagged], ignore_index=True)

# %%
agg = multimodel_df.groupby(['method', 'model', 'pca_var'])['mcc'].mean().reset_index()

fig, axes = plt.subplots(1, len(METHODS), figsize=(20, 7), sharey=True)

for ax, method in zip(axes, METHODS):
    for model_name in MODELS:
        subset = agg[(agg['method'] == method) & (agg['model'] == model_name)]
        subset = subset.set_index('pca_var').reindex(PCA_VARIANTS)
        ax.plot(PCA_VARIANTS, subset['mcc'].values, marker='o',
                color=MODEL_COLORS[model_name], label=MODEL_LABELS[model_name], alpha=LINE_ALPHA)
    ax.set_title(f'Method = {method}', fontsize=TITLE_FS)
    ax.set_xlabel('PCA variance', fontsize=LABEL_FS)
    ax.tick_params(axis='x', rotation=45, labelsize=TICK_FS)
    ax.grid(axis='y', linestyle='--', alpha=GRID_ALPHA)

axes[0].set_ylabel('Mean MCC', fontsize=LABEL_FS)
axes[-1].legend(title='Model', loc='upper right', fontsize=LEGEND_FS)
fig.suptitle('Site classification — CatBoost vs LogReg', fontsize=TITLE_FS + 1, y=1.02)
fig.tight_layout()
fig.savefig(f"{FIGURES_DIR}/site_mcc_multimodel_by_method.png", dpi=SAVE_DPI, bbox_inches='tight')
plt.show()
